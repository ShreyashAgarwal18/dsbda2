# %%
# =========================================================
# TEXT ANALYTICS - PREPROCESSING + TF-IDF
# SINGLE DOCUMENT VERSION
# =========================================================

import nltk
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import pos_tag
from nltk.stem import PorterStemmer, WordNetLemmatizer

# =========================================================
# DOWNLOAD REQUIRED PACKAGES
# =========================================================

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')

# =========================================================
# SAMPLE DOCUMENT
# =========================================================

doc = """
Data science is an interdisciplinary field that uses scientific methods,
algorithms and systems to extract knowledge from structured and unstructured data.
Machine learning is a key part of data science and artificial intelligence.
"""

print("Original Document:\n", doc)

# =========================================================
# 1. TOKENIZATION
# =========================================================

tokens = word_tokenize(doc.lower())
print("\nTokenization:\n", tokens)

# =========================================================
# 2. STOP WORD REMOVAL
# =========================================================

stop_words = set(stopwords.words('english'))

filtered_tokens = [
    word for word in tokens
    if word.isalnum() and word not in stop_words
]

print("\nAfter Stopword Removal:\n", filtered_tokens)

# =========================================================
# 3. POS TAGGING
# =========================================================

pos_tags = pos_tag(filtered_tokens)
print("\nPOS Tagging:\n", pos_tags)

# =========================================================
# 4. STEMMING
# =========================================================

stemmer = PorterStemmer()
stemmed = [stemmer.stem(word) for word in filtered_tokens]

print("\nStemming:\n", stemmed)

# =========================================================
# 5. LEMMATIZATION
# =========================================================

lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print("\nLemmatization:\n", lemmatized)

# =========================================================
# 6. TERM FREQUENCY (TF)
# =========================================================

cv = CountVectorizer()
tf_matrix = cv.fit_transform([doc])

tf_df = pd.DataFrame(tf_matrix.toarray(), columns=cv.get_feature_names_out())

print("\nTerm Frequency (TF):\n")
print(tf_df)

# =========================================================
# 7. INVERSE DOCUMENT FREQUENCY (IDF)
# =========================================================

tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform([doc])

idf_df = pd.DataFrame(
    tfidf.idf_,
    index=tfidf.get_feature_names_out(),
    columns=["IDF"]
)

print("\nInverse Document Frequency (IDF):\n")
print(idf_df)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Subhi
# [nltk_data]     Jain\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Subhi
# [nltk_data]     Jain\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Subhi Jain\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to C:\Users\Subhi
# [nltk_data]     Jain\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Subhi
# [nltk_data]     Jain\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Original Document:
#
# Data science is an interdisciplinary field that uses scientific methods,
# algorithms and systems to extract knowledge from structured and unstructured data.
# Machine learning is a key part of data science and artificial intelligence.
#
#
# Tokenization:
#  ['data', 'science', 'is', 'an', 'interdisciplinary', 'field', 'that', 'uses', 'scientific', 'methods', ',', 'algorithms', 'and', 'systems', 'to', 'extract', 'knowledge', 'from', 'structured', 'and', 'unstructured', 'data', '.', 'machine', 'learning', 'is', 'a', 'key', 'part', 'of', 'data', 'science', 'and', 'artificial', 'intelligence', '.']
#
# After Stopword Removal:
#  ['data', 'science', 'interdisciplinary', 'field', 'uses', 'scientific', 'methods', 'algorithms', 'systems', 'extract', 'knowledge', 'structured', 'unstructured', 'data', 'machine', 'learning', 'key', 'part', 'data', 'science', 'artificial', 'intelligence']
#
# POS Tagging:
#  [('data', 'NNS'), ('science', 'NN'), ('interdisciplinary', 'JJ'), ('field', 'NN'), ('uses', 'VBZ'), ('scientific', 'JJ'), ('methods', 'NNS'), ('algorithms', 'RB'), ('systems', 'NNS'), ('extract', 'JJ'), ('knowledge', 'NN'), ('structured', 'VBD'), ('unstructured', 'JJ'), ('data', 'NNS'), ('machine', 'NN'), ('learning', 'VBG'), ('key', 'JJ'), ('part', 'NN'), ('data', 'NNS'), ('science', 'NN'), ('artificial', 'JJ'), ('intelligence', 'NN')]
#
# Stemming:
#  ['data', 'scienc', 'interdisciplinari', 'field', 'use', 'scientif', 'method', 'algorithm', 'system', 'extract', 'knowledg', 'structur', 'unstructur', 'data', 'machin', 'learn', 'key', 'part', 'data', 'scienc', 'artifici', 'intellig']
#
# Lemmatization:
#  ['data', 'science', 'interdisciplinary', 'field', 'us', 'scientific', 'method', 'algorithm', 'system', 'extract', 'knowledge', 'structured', 'unstructured', 'data', 'machine', 'learning', 'key', 'part', 'data', 'science', 'artificial', 'intelligence']
#
# Term Frequency (TF):
#
#    algorithms  an  and  artificial  data  extract  field  from  intelligence  \
# 0           1   1    3           1     3        1      1     1             1
#
#    interdisciplinary  ...  of  part  science  scientific  structured  systems  \
# 0                  1  ...   1     1        2           1           1        1
#
#    that  to  unstructured  uses
# 0     1   1             1     1
#
# [1 rows x 26 columns]
#
# Inverse Document Frequency (IDF):
#
#                    IDF
# algorithms         1.0
# an                 1.0
# and                1.0
# artificial         1.0
# data               1.0
# extract            1.0
# field              1.0
# from               1.0
# intelligence       1.0
# interdisciplinary  1.0
# is                 1.0
# key                1.0
# knowledge          1.0
# learning           1.0
# machine            1.0
# methods            1.0
# of                 1.0
# part               1.0
# science            1.0
# scientific         1.0
# structured         1.0
# systems            1.0
# that               1.0
# to                 1.0
# unstructured       1.0
# uses               1.0
